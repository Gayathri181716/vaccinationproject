# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random

# %%
data=pd.read_csv("https://raw.githubusercontent.com/owid/covid-19-data/refs/heads/master/public/data/vaccinations/vaccinations.csv")

# %%
data
# Out:
#            location iso_code        date  total_vaccinations  \
# 0       Afghanistan      AFG  2021-02-22                 0.0
# 1       Afghanistan      AFG  2021-02-23                 NaN
# 2       Afghanistan      AFG  2021-02-24                 NaN
# 3       Afghanistan      AFG  2021-02-25                 NaN
# 4       Afghanistan      AFG  2021-02-26                 NaN
# ...             ...      ...         ...                 ...
# 196241     Zimbabwe      ZWE  2022-10-05          12219760.0
# 196242     Zimbabwe      ZWE  2022-10-06                 NaN
# 196243     Zimbabwe      ZWE  2022-10-07                 NaN
# 196244     Zimbabwe      ZWE  2022-10-08                 NaN
# 196245     Zimbabwe      ZWE  2022-10-09          12222754.0
#
#         people_vaccinated  people_fully_vaccinated  total_boosters  \
# 0                     0.0                      NaN             NaN
# 1                     NaN                      NaN             NaN
# ...

# %%
data.shape
# Out:
# (196246, 16)

# %%
data.tail()
# Out:
#         location iso_code        date  total_vaccinations  people_vaccinated  \
# 196241  Zimbabwe      ZWE  2022-10-05          12219760.0          6436704.0
# 196242  Zimbabwe      ZWE  2022-10-06                 NaN                NaN
# 196243  Zimbabwe      ZWE  2022-10-07                 NaN                NaN
# 196244  Zimbabwe      ZWE  2022-10-08                 NaN                NaN
# 196245  Zimbabwe      ZWE  2022-10-09          12222754.0          6437808.0
#
#         people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 196241                4750104.0       1032952.0                     NaN
# 196242                      NaN             NaN                     NaN
# 196243                      NaN             NaN                     NaN
# 196244                      NaN             NaN                     NaN
# 196245                4751270.0       1033676.0                     NaN
#
#         daily_vaccinations  total_vaccinations_per_hundred  \
# ...

# %%
data.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# 0                      NaN             NaN                     NaN
# 1                      NaN             NaN                     NaN
# 2                      NaN             NaN                     NaN
# 3                      NaN             NaN                     NaN
# 4                      NaN             NaN                     NaN
#
#    daily_vaccinations  total_vaccinations_per_hundred  \
# ...

# %%
data.location.unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
data.location.nunique()
# Out:
# 235

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 196246 entries, 0 to 196245
# Data columns (total 16 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   location                             196246 non-null  object
#  1   iso_code                             196246 non-null  object
#  2   date                                 196246 non-null  object
#  3   total_vaccinations                   85417 non-null   float64
#  4   people_vaccinated                    81132 non-null   float64
#  5   people_fully_vaccinated              78061 non-null   float64
#  6   total_boosters                       53600 non-null   float64
#  7   daily_vaccinations_raw               70971 non-null   float64
#  8   daily_vaccinations                   195029 non-null  float64
#  9   total_vaccinations_per_hundred       85417 non-null   float64
# ...

# %%
data.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        8.541700e+04       8.113200e+04             7.806100e+04
# mean         5.616980e+08       2.487064e+08             2.286639e+08
# std          1.842160e+09       8.006461e+08             7.403763e+08
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.970788e+06       1.050009e+06             9.644000e+05
# 50%          1.439435e+07       6.901088e+06             6.191345e+06
# 75%          1.161972e+08       5.093295e+07             4.773185e+07
# max          1.357877e+10       5.631264e+09             5.177943e+09
#
#        total_boosters  daily_vaccinations_raw  daily_vaccinations  \
# count    5.360000e+04            7.097100e+04        1.950290e+05
# mean     1.505811e+08            7.398640e+05        2.838758e+05
# std      4.360697e+08            3.183064e+06        1.922352e+06
# min      1.000000e+00            0.000000e+00        0.000000e+00
# ...

# %%
data[data['location'] == "Italy"]
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 88299    Italy      ITA  2020-12-27              7191.0             7191.0
# 88300    Italy      ITA  2020-12-28              8696.0             8696.0
# 88301    Italy      ITA  2020-12-29              9795.0             9795.0
# 88302    Italy      ITA  2020-12-30             14689.0            14689.0
# 88303    Italy      ITA  2020-12-31             40667.0            40667.0
# ...        ...      ...         ...                 ...                ...
# 89349    Italy      ITA  2023-11-12         144608699.0         50936715.0
# 89350    Italy      ITA  2023-11-13         144608728.0         50936715.0
# 89351    Italy      ITA  2023-11-14         144608768.0         50936718.0
# 89352    Italy      ITA  2023-11-15         144608813.0         50936718.0
# 89353    Italy      ITA  2023-11-16         144608839.0         50936719.0
#
# ...

# %%
data[data['location'] == "Germany"]
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 67292  Germany      DEU  2020-12-27             24427.0            24427.0
# 67293  Germany      DEU  2020-12-28             42500.0            42500.0
# 67294  Germany      DEU  2020-12-29             92729.0            92729.0
# 67295  Germany      DEU  2020-12-30            156942.0           156942.0
# 67296  Germany      DEU  2020-12-31            206927.0           206927.0
# ...        ...      ...         ...                 ...                ...
# 68119  Germany      DEU  2023-04-03         192212196.0         64876099.0
# 68120  Germany      DEU  2023-04-04         192214629.0         64876150.0
# 68121  Germany      DEU  2023-04-05         192217111.0         64876210.0
# 68122  Germany      DEU  2023-04-06         192220523.0         64876298.0
# 68123  Germany      DEU  2023-04-07         192221468.0         64876299.0
#
# ...

# %%
data.drop_duplicates(['daily_vaccinations_raw','daily_vaccinations','daily_people_vaccinated','daily_people_vaccinated_per_hundred'],keep = 'first', inplace = True)

# %%
data.isnull()
# Out:
#         location  iso_code   date  total_vaccinations  people_vaccinated  \
# 0          False     False  False               False              False
# 1          False     False  False                True               True
# 7          False     False  False                True               True
# 8          False     False  False                True               True
# 9          False     False  False                True               True
# ...          ...       ...    ...                 ...                ...
# 196241     False     False  False               False              False
# 196242     False     False  False                True               True
# 196243     False     False  False                True               True
# 196244     False     False  False                True               True
# 196245     False     False  False               False              False
#
#         people_fully_vaccinated  total_boosters  daily_vaccinations_raw  \
# ...

# %%
data.shape
# Out:
# (133535, 16)

# %%
data.isnull().sum()
# Out:
# location                                   0
# iso_code                                   0
# date                                       0
# total_vaccinations                     54029
# people_vaccinated                      58069
# people_fully_vaccinated                60691
# total_boosters                         83503
# daily_vaccinations_raw                 63967
# daily_vaccinations                       226
# total_vaccinations_per_hundred         54029
# people_vaccinated_per_hundred          58069
# people_fully_vaccinated_per_hundred    60691
# total_boosters_per_hundred             83503
# daily_vaccinations_per_million           226
# daily_people_vaccinated                 2148
# daily_people_vaccinated_per_hundred     2148
# dtype: int64

# %%
data['total_vaccinations']
# Out:
# 0                0.0
# 1                NaN
# 7                NaN
# 8                NaN
# 9                NaN
#              ...
# 196241    12219760.0
# 196242           NaN
# 196243           NaN
# 196244           NaN
# 196245    12222754.0
# Name: total_vaccinations, Length: 133535, dtype: float64

# %%
data['total_vaccinations'].unique()
# Out:
# array([       0.,       nan,   573277., ..., 12216848., 12219760.,
#        12222754.])

# %%
data['total_vaccinations'].nunique()
# Out:
# 78250

# %%
print(data['total_vaccinations'].unique()[0])
# Out:
# 0.0

# %%
print(data['total_vaccinations'].unique()[5])
# Out:
# 600152.0

# %%
data['total_vaccinations'] = data['total_vaccinations'].astype(str)
data['total_vaccinations'] = data['total_vaccinations'].apply(lambda x: x[2:-2] if isinstance(x, str) and len(x) >= 4 else x)
print(data['total_vaccinations'].unique())
# Out:
# ['0.0' 'nan' '3277' ... '216848' '219760' '222754']

# %%
data['total_vaccinations'] = data['total_vaccinations'].apply(lambda x: np.where(x == "","NA",x))
print(data['total_vaccinations'].unique())
# Out:
# ['0.0' 'nan' '3277' ... '216848' '219760' '222754']

# %%
data['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Asia', 'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
# ...

# %%
len(data['location'].unique())
# Out:
# 234

# %%
outlets = data['location'].value_counts()

# %%
outlets
# Out:
# location
# High income                        1334
# World                              1333
# Asia                               1328
# North America                      1317
# Canada                             1316
#                                    ...
# Tokelau                              30
# Falkland Islands                     29
# Saint Helena                         22
# Turkmenistan                         22
# Bonaire Sint Eustatius and Saba       1
# Name: count, Length: 234, dtype: int64

# %%
chains = outlets[outlets >= 2]
single  = outlets[outlets == 1]

# %%
single
# Out:
# location
# Bonaire Sint Eustatius and Saba    1
# Name: count, dtype: int64

# %%
chains
# Out:
# location
# High income         1334
# World               1333
# Asia                1328
# North America       1317
# Canada              1316
#                     ...
# Niue                  30
# Tokelau               30
# Falkland Islands      29
# Saint Helena          22
# Turkmenistan          22
# Name: count, Length: 233, dtype: int64

# %%
data.shape
# Out:
# (133535, 16)

# %%
chains.shape
# Out:
# (233,)

# %%
single.shape
# Out:
# (1,)

# %%
print("total vaccinations in our data = ", data.shape[0])

print("total vaccinations that are part of some chain = ", data.shape[0] - single.shape[0])

print("percentage of vaccinations that are part of some chain = ", np.round((data.shape[0] - single.shape[0]) / data.shape[0],2)*100, "%")
# Out:
# total vaccinations in our data =  133535
# total vaccinations that are part of some chain =  133534
# percentage of vaccinations that are part of some chain =  100.0 %

# %%
chains.head()
# Out:
# location
# High income      1334
# World            1333
# Asia             1328
# North America    1317
# Canada           1316
# Name: count, dtype: int64

# %%
top10_foodchains = data['location'].value_counts()[:10].sort_values(ascending = True)

# %%
top10_foodchains
# Out:
# location
# Lower middle income    1227
# Malaysia               1235
# India                  1273
# Upper middle income    1279
# Europe                 1312
# Canada                 1316
# North America          1317
# Asia                   1328
# World                  1333
# High income            1334
# Name: count, dtype: int64

# %%
height = top10_foodchains.values
bars = top10_foodchains.index
y_pos = np.arange(len(bars))

fig = plt.figure(figsize = [11,8], frameon = False)
ax = fig.gca()
ax.spines['top'].set_visible("#424242")
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color("#424242")
ax.spines['bottom'].set_color("#424242")

colors = ['#f9cdac', '#f2a49f', '#ec7c92', '#e65586','#bc438b', '#933291','#692398','#551c7b','#41155e','#2d0f41']

plt.barh(y_pos, height, color = colors)

plt.xticks(color = "#424242")
plt.yticks(y_pos, bars, color = "#424242")
plt.xlabel("Number of outlets in world")

for i, v in enumerate(height):
    plt.text(v + 3, i, str(v), color = 'black', fontweight = 'bold')
plt.title(" Maximum vaccinations chains in world")
plt.show()

# %%
height = top10_foodchains.values
bars = top10_foodchains.index
y_pos = np.arange(len(bars))

fig = plt.figure(figsize=[11,8], frameon=False)
ax = fig.gca()

# Set spine colors
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_color("#424242")
ax.spines['bottom'].set_color("#424242")

colors = ['#f9cdac', '#f2a49f', '#ec7c92', '#e65586',
          '#bc438b', '#933291', '#692398', '#551c7b', '#41155e', '#2d0f41']

plt.barh(y_pos, height, color=colors)

plt.xticks(color="#424242")
plt.yticks(y_pos, bars, color="#424242")
plt.xlabel("Number of Outlets in world", fontsize=12, color="#424242")
plt.title("Maximum vaccinations Chains in world", fontsize=16, color="#424242")

for i, v in enumerate(height):
    plt.text(v + 3, i, str(v), color='black', fontweight='bold')

plt.xlim(0, max(height) + 20)  # Prevent clipping
plt.tight_layout()
plt.show()

# %%
outlets = data['location'].value_counts()

# %%
outlets
# Out:
# location
# High income                        1334
# World                              1333
# Asia                               1328
# North America                      1317
# Canada                             1316
#                                    ...
# Tokelau                              30
# Falkland Islands                     29
# Saint Helena                         22
# Turkmenistan                         22
# Bonaire Sint Eustatius and Saba       1
# Name: count, Length: 234, dtype: int64

# %%
Min_outlets = outlets[outlets > 5]

# %%
Min_outlets
# Out:
# location
# High income         1334
# World               1333
# Asia                1328
# North America       1317
# Canada              1316
#                     ...
# Niue                  30
# Tokelau               30
# Falkland Islands      29
# Saint Helena          22
# Turkmenistan          22
# Name: count, Length: 233, dtype: int64

# %%
data['total_vaccinations'] = data['total_vaccinations'].replace("NA", np.nan)
data['total_vaccinations'] = pd.to_numeric(data['total_vaccinations'], errors='coerce')
top10_chains2 = data[
    data["location"].isin(Min_outlets.index)
].groupby("location")["total_vaccinations"].mean().sort_values(ascending=False)[:10].sort_values(ascending=True)

# %%
top10_chains2
# Out:
# location
# South America          4.981783e+06
# India                  2.348752e+07
# North America          3.115778e+07
# High income            3.580497e+07
# Lower middle income    3.861090e+07
# Asia                   3.876730e+07
# Upper middle income    4.048312e+07
# China                  4.092071e+07
# Europe                 5.615966e+07
# World                  3.642284e+08
# Name: total_vaccinations, dtype: float64

# %%
height = pd.Series(top10_chains2.values).map(lambda x : np.round(x, 2))
bars = top10_chains2.index
y_pos = np.arange(len(bars))

fig = plt.figure(figsize=[11,7], frameon=False)
ax = fig.gca()
ax.spines["top"].set_visible("#424242")
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color("#424242")
ax.spines["bottom"].set_color("#424242")

colors = ["green","blue","magenta","cyan","gray","yellow","purple","violet","orange","red","maroon"]
random.shuffle(colors)

#colors = ['#fded86', '#fce36b', '#f7c65d', '#f1a84f', '#ec8c41', '#e76f34', '#e25328', '#b04829', '#7e3e2b', '#4c3430']
plt.barh(y_pos, height, color=colors)

plt.xlim(3)
plt.xticks(color="#424242")
plt.yticks(y_pos, bars, color="#424242")
plt.xlabel("Number of outlets in world")

for i, v in enumerate(height):
    ax.text(v + 0.01, i, str(v), color='#424242')
plt.title("Maximum vaccinations chain(by average vaccinations)")
# Out:
# Text(0.5, 1.0, 'Maximum vaccinations chain(by average vaccinations)')

# %% [markdown]
# Conclusion:
#
# This project was done using a COVID-19 vaccination dataset from around the world.
#
# The goal was to find which countries gave the most vaccines.
#
# I cleaned the data by removing repeated and missing values.
#
# I looked at the data for each country and compared vaccination numbers.
#
# I found the top 10 countries with the highest total and average vaccinations.
#
# I used bar charts to show the results clearly.
#
# This project helped us understand which countries performed best in giving vaccines during COVID-19.
